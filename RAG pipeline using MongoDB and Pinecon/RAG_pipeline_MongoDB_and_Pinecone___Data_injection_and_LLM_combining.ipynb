# %%
# !pip install datasets

# %%
# !pip install pandas

# %%
from datasets import load_dataset

# %%
dataset=load_dataset("MongoDB/embedded_movies")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['plot', 'runtime', 'genres', 'fullplot', 'directors', 'writers', 'countries', 'poster', 'languages', 'cast', 'title', 'num_mflix_comments', 'rated', 'imdb', 'awards', 'type', 'metacritic', 'plot_embedding'],
#         num_rows: 1500
#     })
# })

# %%
import pandas as pd
data = pd.DataFrame(dataset["train"])

# %%
data.head()
# Out:
#                                                 plot  runtime  \
# 0  Young Pauline is left a lot of money when her ...    199.0
# 1  A penniless young man tries to save an heiress...     22.0
# 2  Michael "Beau" Geste leaves England in disgrac...    101.0
# 3  Seeking revenge, an athletic young man joins t...     88.0
# 4  An irresponsible young millionaire changes his...     58.0
#
#                        genres  \
# 0                    [Action]
# 1     [Comedy, Short, Action]
# 2  [Action, Adventure, Drama]
# 3         [Adventure, Action]
# 4   [Action, Comedy, Romance]
#
#                                             fullplot  \
# 0  Young Pauline is left a lot of money when her ...
# 1  As a penniless man worries about how he will m...
# 2  Michael "Beau" Geste leaves England in disgrac...
# 3  A nobleman vows to avenge the death of his fat...
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...
#
#                               directors  \
# ...

# %%
data.shape
# Out:
# (1500, 18)

# %%
data=data.sample(80)

# %%
data.columns
# Out:
# Index(['plot', 'runtime', 'genres', 'fullplot', 'directors', 'writers',
#        'countries', 'poster', 'languages', 'cast', 'title',
#        'num_mflix_comments', 'rated', 'imdb', 'awards', 'type', 'metacritic',
#        'plot_embedding'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# plot                   2
# runtime                1
# genres                 0
# fullplot               2
# directors              1
# writers                1
# countries              0
# poster                 8
# languages              0
# cast                   0
# title                  0
# num_mflix_comments     0
# rated                 17
# imdb                   0
# awards                 0
# type                   0
# metacritic            56
# plot_embedding         2
# dtype: int64

# %%
data=data.dropna(subset=["fullplot"])

# %%
data=data.drop(columns=["plot_embedding"])

# %%
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# ...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
# !pip install pymongo
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://kartavyamaster17:kartavya@cluster0.jjy9v.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ...
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['mytestdb']
collection = db['mytestcollection']

# %%
document=data.to_dict("records")

# %%
collection.insert_many(document)
# Out:
# InsertManyResult([ObjectId('66eabbb32e2aeb2986af6daa'), ObjectId('66eabbb32e2aeb2986af6dab'), ObjectId('66eabbb32e2aeb2986af6dac'), ObjectId('66eabbb32e2aeb2986af6dad'), ObjectId('66eabbb32e2aeb2986af6dae'), ObjectId('66eabbb32e2aeb2986af6daf'), ObjectId('66eabbb32e2aeb2986af6db0'), ObjectId('66eabbb32e2aeb2986af6db1'), ObjectId('66eabbb32e2aeb2986af6db2'), ObjectId('66eabbb32e2aeb2986af6db3'), ObjectId('66eabbb32e2aeb2986af6db4'), ObjectId('66eabbb32e2aeb2986af6db5'), ObjectId('66eabbb32e2aeb2986af6db6'), ObjectId('66eabbb32e2aeb2986af6db7'), ObjectId('66eabbb32e2aeb2986af6db8'), ObjectId('66eabbb32e2aeb2986af6db9'), ObjectId('66eabbb32e2aeb2986af6dba'), ObjectId('66eabbb32e2aeb2986af6dbb'), ObjectId('66eabbb32e2aeb2986af6dbc'), ObjectId('66eabbb32e2aeb2986af6dbd'), ObjectId('66eabbb32e2aeb2986af6dbe'), ObjectId('66eabbb32e2aeb2986af6dbf'), ObjectId('66eabbb32e2aeb2986af6dc0'), ObjectId('66eabbb32e2aeb2986af6dc1'), ObjectId('66eabbb32e2aeb2986af6dc2'), ObjectId('66eabbb32e2aeb2986af
# ...

# %%
from google.colab import userdata
PINECONE_API_KEY=userdata.get('PINECONE_API_KEY')

# %%
# !pip install pinecone-client
from pinecone import Pinecone
pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index("mongo")

# %%
def get_result(query,similar_result=5):
  embedding=embedding_model.encode(query)
  embedding=embedding.tolist()

  result=index.query(
    vector=embedding,
    top_k=similar_result,
  )
  return result

# %%
query = "suggest top 3 comedy movie along with its reason "

# %%
result=get_result(query)

# %%
result
# Out:
# {'matches': [{'id': '66eaba792e2aeb2986af6d83',
#               'score': 0.307745546,
#               'values': []},
#              {'id': '66eab9662e2aeb2986af6c43',
#               'score': 0.307335109,
#               'values': []},
#              {'id': '66eabbb32e2aeb2986af6dd3',
#               'score': 0.307335109,
#               'values': []},
#              {'id': '66eab9662e2aeb2986af6cb2',
#               'score': 0.305555582,
#               'values': []},
#              {'id': '66eaba312e2aeb2986af6cd6',
#               'score': 0.291678071,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 5}}

# %%
from bson.objectid import ObjectId

# %%
mylist=[]
for i in  range(len(result["matches"])):
  value=result["matches"][i]['id']
  mylist.append(collection.find_one({"_id": ObjectId(value)}))

# %%
mylist
# Out:
# [{'_id': ObjectId('66eaba792e2aeb2986af6d83'),
#   'plot': 'A cop, a lawyer, and an assassin cross paths after the murder of a federal witness and the kidnapping of a famous pop star.',
#   'runtime': 101.0,
#   'genres': ['Action', 'Crime'],
#   'fullplot': "This thriller has Suen chasing some gangsters around Hong Kong. One of his key witnesses is assassinated after being extradited from Canada and that puts an end to the prosecution's case. Meanwhile, Suen is still struggling with his girlfriends disappearance 10 years ago. A pair of assassins fill out the third plot chain. The gangsters, Suen, and the assassins intersect often as they try to solve the crimes and find out what happened to Suen's girlfriend.",
#   'directors': ['Benny Chan'],
#   'writers': ['Ivy Ho'],
#   'countries': ['Hong Kong'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTI0NzUyMDE1M15BMl5BanBnXkFtZTcwNTkyMjM0MQ@@._V1_SY1000_SX677_AL_.jpg',
#   'languages': ['Cantonese', 'Mandarin', 'English'],
# ...

# %%
combined_information = ""
for i in range(len(mylist)):
  fullplot=mylist[i]["fullplot"]
  title=mylist[i]["title"]
  combined_information += f"Title:{title}, fullplot: {fullplot}\n"

# %%
print(combined_information)
# Out:
# Title:Divergence, fullplot: This thriller has Suen chasing some gangsters around Hong Kong. One of his key witnesses is assassinated after being extradited from Canada and that puts an end to the prosecution's case. Meanwhile, Suen is still struggling with his girlfriends disappearance 10 years ago. A pair of assassins fill out the third plot chain. The gangsters, Suen, and the assassins intersect often as they try to solve the crimes and find out what happened to Suen's girlfriend.
# Title:Biteu, fullplot: This movie follows the story of three friends in Korea, all three of whom drop out of school. The main character is Min, a tough guy whose widowed mother is a drunk. The story traces his journey from high school to the underworld as one of his friends introduces him to life in the mob. Complicating Min's life further is his romance with Romi, a girl from an upper-class family with dreams of going to a prestigious college.
# ...

# %%
query
# Out:
# 'suggest top 3 comedy movie along with its reason '

# %%
prompt = f"Query: {query}\nContinue to answer the query by using the fullplot only:{combined_information}.\nGive extrain formation of movies from web too."

# %%
print(prompt)
# Out:
# Query: suggest top 3 comedy movie along with its reason
# Continue to answer the query by using the fullplot only:Title:Divergence, fullplot: This thriller has Suen chasing some gangsters around Hong Kong. One of his key witnesses is assassinated after being extradited from Canada and that puts an end to the prosecution's case. Meanwhile, Suen is still struggling with his girlfriends disappearance 10 years ago. A pair of assassins fill out the third plot chain. The gangsters, Suen, and the assassins intersect often as they try to solve the crimes and find out what happened to Suen's girlfriend.
# ...

# %%
# %pip install --upgrade  langchain-google-genai

# %%
import os
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
def load_model(model_name):
  if model_name=="gemini-pro":
    llm = ChatGoogleGenerativeAI(model="gemini-pro")
  else:
    llm=ChatGoogleGenerativeAI(model="gemini-pro-vision")

  return llm

# %%
model_text=load_model("gemini-pro")

# %%
prompt
# Out:
# "Query: suggest top 3 comedy movie along with its reason \nContinue to answer the query by using the fullplot only:Title:Divergence, fullplot: This thriller has Suen chasing some gangsters around Hong Kong. One of his key witnesses is assassinated after being extradited from Canada and that puts an end to the prosecution's case. Meanwhile, Suen is still struggling with his girlfriends disappearance 10 years ago. A pair of assassins fill out the third plot chain. The gangsters, Suen, and the assassins intersect often as they try to solve the crimes and find out what happened to Suen's girlfriend.\nTitle:Biteu, fullplot: This movie follows the story of three friends in Korea, all three of whom drop out of school. The main character is Min, a tough guy whose widowed mother is a drunk. The story traces his journey from high school to the underworld as one of his friends introduces him to life in the mob. Complicating Min's life further is his romance with Romi, a girl from an upper-class
# ...

# %%
print(model_text.invoke(prompt).content)
# Out:
# 1. **Rush Hour 2** (2001)
#
# **Reason:** This action comedy is a hilarious and exciting ride, with Chris Tucker and Jackie Chan at their best. The film is full of over-the-top action sequences, laugh-out-loud moments, and a great chemistry between the two leads.
#
# ...
